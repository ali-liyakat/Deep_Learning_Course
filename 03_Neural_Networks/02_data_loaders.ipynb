# %% [markdown]
# ## PyTorch Datasets and DataLoaders

# %%
import torch
from torchvision import datasets
from torchvision.transforms import ToTensor
from matplotlib import pyplot as plt

# %% [markdown]
# ### FashionMNIST DataSet

# %%
training_data = datasets.FashionMNIST(
    root="data",
    download=True,
    train=True, 
    transform=ToTensor()
)


test_data = datasets.FashionMNIST(
    root="data",
    download=True,
    train=False, 
    transform=ToTensor()
)

# %%
len(training_data)
# Out:
# 60000

# %%
len(test_data)
# Out:
# 10000

# %%
labels_map = {
    0: "T-Shirt/Top",
    1: "Trouser",
    2: "Pullover",
    3: "Dress",
    4: "Coat",
    5: "Sandal",
    6: "Shirt",
    7: "Sneaker",
    8: "Bag",
    9: "Ankle Boot"
}

# %%
image, label = training_data[0]

# %%
label
# Out:
# 9

# %%
labels_map[label]
# Out:
# 'Ankle Boot'

# %%
image.shape
# Out:
# torch.Size([1, 28, 28])

# %%
plt.figure(figsize=(2, 2))
plt.imshow(image.squeeze(), cmap='grey')
plt.show()

# %%
fig, axes = plt.subplots(3, 3, figsize=(10, 7))

for i, ax in enumerate(axes.flat):
    image, label = training_data[i]
    ax.imshow(image.squeeze(), cmap="gray")
    ax.set_title(f"Label: {label}")
    ax.axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Data Loaders

# %%
from torch.utils.data import DataLoader

# %%
train_data_loader = DataLoader(training_data, batch_size=64, shuffle=True)
train_data_loader = DataLoader(test_data, batch_size=64, shuffle=True)

# %%
data_iter = iter(train_data_loader)
images, labels = next(data_iter)

# %%
labels
# Out:
# tensor([0, 3, 8, 5, 0, 8, 1, 3, 7, 9, 5, 7, 6, 5, 4, 1, 7, 2, 9, 3, 4, 4, 7, 5,
#         6, 0, 3, 8, 5, 4, 7, 7, 1, 7, 5, 9, 5, 5, 4, 0, 0, 7, 0, 8, 9, 9, 5, 0,
#         8, 3, 7, 1, 8, 3, 6, 0, 7, 7, 8, 2, 5, 5, 5, 5])

# %%
images.shape
# Out:
# torch.Size([64, 1, 28, 28])

# %%
plt.figure(figsize=(4,4))
plt.imshow(images[0].squeeze(), cmap='gray')
plt.show()

# %%
labels_map[labels[0].item()]
# Out:
# 'T-Shirt/Top'
